# %%
import pandas as pd
import numpy as np

# Replace 'your_file.xlsx' with the actual file path
file_path = 'Anomaly_icin_data.xlsx'

# Read the data from the Excel file into a DataFrame
df = pd.read_excel(file_path)
# Group the data by 'KPI_ID'
grouped = df.groupby('KPI_ID')

# Define a function to identify anomalies based on the IQR method
def find_anomalies(group):
    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = group['VALUE_YTD'].quantile(0.25)
    Q3 = group['VALUE_YTD'].quantile(0.75)

    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1

    # Define a multiplier (e.g., 1.5) to determine the anomaly threshold
    multiplier = 1.5  # Adjust this multiplier as needed

    # Calculate the lower and upper bounds for anomalies
    lower_bound = Q1 - multiplier * IQR
    upper_bound = Q3 + multiplier * IQR

    # Identify anomalies
    anomalies = group[(group['VALUE_YTD'] < lower_bound) | (group['VALUE_YTD'] > upper_bound)]

    return anomalies

# Create an empty DataFrame to store anomalies
anomalies_df = pd.DataFrame(columns=df.columns)

# Iterate through groups and find anomalies for each 'KPI_ID'
for kpi_id, group_data in grouped:
    anomalies = find_anomalies(group_data)
    anomalies_df = pd.concat([anomalies_df, anomalies], ignore_index=True)


# Print the anomalies DataFrame
print(anomalies_df)
# Out:
#       DATETIME KOTU_YTD LEVEL_ID LEVEL_ELEMENT KPI_ID  \
# 0   2023-07-20      ALT       34      ISTANBUL   1001
# 1   2023-07-21      ALT       34      ISTANBUL   1001
# 2   2023-07-25      ALT       34      ISTANBUL   1001
# 3   2023-08-09      ALT       34      ISTANBUL   1001
# 4   2023-08-10      ALT       34      ISTANBUL   1001
# ..         ...      ...      ...           ...    ...
# 170 2023-08-08      ALT       34      ISTANBUL   6133
# 171 2023-07-22      ALT       34      ISTANBUL   6134
# 172 2023-07-31      ALT       34      ISTANBUL   6134
# 173 2023-08-04      ALT       34      ISTANBUL   6134
# 174 2023-08-08      ALT       34      ISTANBUL   6134
#
#                                               KPI_NAME  VALUE_YTD
# 0                            CQI-2G AVG. ACCESSIBILITY  99.207824
# 1                            CQI-2G AVG. ACCESSIBILITY  99.383825
# 2                            CQI-2G AVG. ACCESSIBILITY  99.478129
# 3                            CQI-2G AVG. ACCESSIBILITY  99.485128
# 4                            CQI-2G AVG. ACCESSIBILITY  99.540262
# ..                                                 ...        ...
# 170  KPI-FTTB POP (SWITCH) AVAILABILITY (%)-PLANLI ...  98.905691
# 171  KPI-FTTB POP (SWITCH) GUNDUZ AVAILABILITY (%)-...  99.889314
# 172  KPI-FTTB POP (SWITCH) GUNDUZ AVAILABILITY (%)-...  99.934288
# 173  KPI-FTTB POP (SWITCH) GUNDUZ AVAILABILITY (%)-...  99.876618
# 174  KPI-FTTB POP (SWITCH) GUNDUZ AVAILABILITY (%)-...  98.358536
#
# [175 rows x 7 columns]

# %%
# Count the occurrences of each unique KPI_ID in the anomalies_df DataFrame
kpi_counts = anomalies_df['KPI_ID'].value_counts()

# Find the KPI_ID with the highest count (most anomalies)
most_anomalous_kpi = kpi_counts.idxmax()

# Find the count of anomalies for the most anomalous KPI
most_anomalous_kpi_count = kpi_counts.max()

# Print the most anomalous KPI and its anomaly count
print(f"The most anomalous KPI is KPI_ID {most_anomalous_kpi} with {most_anomalous_kpi_count} anomalies.")
# Out:
# The most anomalous KPI is KPI_ID 6133 with 6 anomalies.

# %%
# Define a function to identify anomalies based on a threshold
def find_anomalies(group):
    mean = group['VALUE_YTD'].mean()
    std_dev = group['VALUE_YTD'].std()
    threshold = 3  # Adjust this threshold as needed

    anomalies = group[(group['VALUE_YTD'] > mean + threshold * std_dev) |
                       (group['VALUE_YTD'] < mean - threshold * std_dev)]

    return anomalies

# Create an empty DataFrame to store anomalies
anomalies_df = pd.DataFrame(columns=df.columns)

# Iterate through groups and find anomalies for each 'KPI_ID'
for kpi_id, group_data in grouped:
    anomalies = find_anomalies(group_data)
    anomalies_df = pd.concat([anomalies_df, anomalies], ignore_index=True)

# Print the anomalies DataFrame
print(anomalies_df)
# Out:
#      DATETIME KOTU_YTD LEVEL_ID LEVEL_ELEMENT KPI_ID  \
# 0  2023-07-20      ALT       34      ISTANBUL   1001
# 1  2023-07-20      ALT       34      ISTANBUL   1003
# 2  2023-07-26      UST       34      ISTANBUL   1005
# 3  2023-07-26      UST       34      ISTANBUL   1014
# 4  2023-07-26      ALT       34      ISTANBUL   1017
# 5  2023-07-26      ALT       34      ISTANBUL   1018
# 6  2023-08-16      ALT       34      ISTANBUL   1019
# 7  2023-07-30      UST       34      ISTANBUL   1023
# 8  2023-08-16      UST       34      ISTANBUL   1025
# 9  2023-07-24      ALT       34      ISTANBUL   1035
# 10 2023-07-25      ALT       34      ISTANBUL   1038
# 11 2023-07-25      UST       34      ISTANBUL   1042
# 12 2023-07-26      ALT       34      ISTANBUL   1044
# 13 2023-07-26      ALT       34      ISTANBUL   1045
# 14 2023-08-16      ALT       34      ISTANBUL   1064
# 15 2023-07-26      ALT       34      ISTANBUL   1067
# 16 2023-08-08      ALT       34      ISTANBUL   1091
# 17 2023-08-10      ALT       34      ISTANBUL   1110
# 18 2023-07-27      ALT       34      ISTANBUL   1114
# 19 2023-07-25      ALT       34      ISTANBUL   1149
# 20 2023-08-16      ALT       34      ISTANBUL   1150
# 21 2023-08-17      UST       34      ISTANBUL   1156
# 22 2023-08-17      UST       34      ISTANBUL   1158
# 23 2023-07-25      UST       34      ISTANBUL   1182
# 24 2023-07-25      UST       34      ISTANBUL   1201
# 25 2023-07-25      ALT       34      ISTANBUL   6100
# 26 2023-08-08      ALT       34      ISTANBUL   6101
# 27 2023-08-08      ALT       34      ISTANBUL   6102
# 28 2023-08-04      ALT       34      ISTANBUL   6104
# 29 2023-08-08      ALT       34      ISTANBUL   6105
# 30 2023-08-08      ALT       34      ISTANBUL   6106
# 31 2023-08-08      ALT       34      ISTANBUL   6117
# 32 2023-08-08      ALT       34      ISTANBUL   6118
# 33 2023-08-08      ALT       34      ISTANBUL   6119
# 34 2023-08-08      ALT       34      ISTANBUL   6120
# 35 2023-08-08      ALT       34      ISTANBUL   6121
# 36 2023-08-08      ALT       34      ISTANBUL   6122
# 37 2023-08-08      ALT       34      ISTANBUL   6123
# 38 2023-08-08      ALT       34      ISTANBUL   6124
# 39 2023-07-25      ALT       34      ISTANBUL   6125
# 40 2023-08-04      ALT       34      ISTANBUL   6126
# 41 2023-08-08      ALT       34      ISTANBUL   6127
# 42 2023-08-08      ALT       34      ISTANBUL   6128
# 43 2023-08-08      ALT       34      ISTANBUL   6129
# 44 2023-08-08      ALT       34      ISTANBUL   6130
# 45 2023-08-08      ALT       34      ISTANBUL   6131
# 46 2023-08-08      ALT       34      ISTANBUL   6132
# 47 2023-08-08      ALT       34      ISTANBUL   6133
# 48 2023-08-08      ALT       34      ISTANBUL   6134
#
#                                              KPI_NAME   VALUE_YTD
# 0                           CQI-2G AVG. ACCESSIBILITY   99.207824
# 1                         CQI-2G3G AVG. ACCESSIBILITY   99.605132
# 2                                    CQI-3G AVG. DROP    0.388967
# 3                                         KPI-3G DROP    0.423694
# 4                  KPI-2G3G DATA TRAFFIC AVAILABILITY   99.805826
# 5                   KPI-2G3G SES TRAFFIC AVAILABILITY   99.795665
# 6                             KPI-3G CS ACCESSIBILITY   99.801288
# 7                            KPI-TWAMP LTE DELAY (MS)    3.407647
# 8                            KPI-TWAMP LTE PACKETLOSS    0.072878
# 9              KPI-3G AVG HSDPA USER THROUGHPUT(MBPS)    3.119159
# 10                            KPI-VOLTE ACCESSIBILITY   99.968912
# 11                                     CQI-VOLTE DROP    0.309260
# 12        KPI-2G3G DATA TRAFFIC AVAILABILITY AUTO-MAN   97.265284
# 13         KPI-2G3G SES TRAFFIC AVAILABILITY AUTO-MAN   97.259516
# 14                            KPI-SRVCC TO CALL VOLTE    2.630247
# 15                KPI-4.5G VOICE TRAFFIC AVAILABILITY   99.806589
# 16                              CQI-RTT UL 4.5G HTTPS   48.135610
# 17                        KPI-INTER FREQ HO SUCC PC %  100.698315
# 18                     KPI-DOWNTIME_AUTO_AVAILABILITY   99.794118
# 19                                      CQI-DROP RATE    0.352162
# 20                      KPI-3G-VOLTE CS ACCESSIBILITY   99.927595
# 21                      KPI-SILENCE DL VOLTE ERICSSON    2.323881
# 22                      KPI-SILENCE UL VOLTE ERICSSON    2.204480
# 23                                  CQI-3G-VOLTE DROP    0.319788
# 24                                     3G OVER SECTOR    0.005262
# 25                           KPI-OLT AVAILABILITY (%)   99.711732
# 26                 KPI-FTTB (SWITCH) AVAILABILITY (%)   99.403825
# 27                    KPI-FIBER SITE AVAILABILITY (%)   99.302801
# 28                    KPI-OLT GUNDUZ AVAILABILITY (%)   99.892520
# 29          KPI-FTTB (SWITCH) GUNDUZ AVAILABILITY (%)   99.112246
# 30             KPI-FIBER SITE GUNDUZ AVAILABILITY (%)   98.980156
# 31            KPI-FTTB CORE (SWITCH) AVAILABILITY (%)   96.672081
# 32     KPI-FTTB CORE (SWITCH) GUNDUZ AVAILABILITY (%)   95.020785
# 33  KPI-FTTB CORE (SWITCH) AVAILABILITY (%)-PLANLI...   96.672081
# 34  KPI-FTTB CORE (SWITCH) GUNDUZ AVAILABILITY (%)...   95.020785
# 35          KPI-FTTB ACCESS (SWITCH) AVAILABILITY (%)   99.605367
# 36   KPI-FTTB ACCESS (SWITCH) GUNDUZ AVAILABILITY (%)   99.414105
# 37  KPI-FTTB ACCESS (SWITCH) AVAILABILITY (%)-PLAN...   99.605367
# 38  KPI-FTTB ACCESS (SWITCH) GUNDUZ AVAILABILITY (...   99.414105
# 39              KPI-OLT AVAILABILITY (%)-PLANLI HARIC   99.711732
# 40       KPI-OLT GUNDUZ AVAILABILITY (%)-PLANLI HARIC   99.892520
# 41        KPI-FIBER SITE AVAILABILITY (%)-PLNLI HARIC   99.302801
# 42  KPI-FIBER SITE GUNDUZ AVAILABILITY (%)-PLANLI ...   98.980156
# 43    KPI-FTTB (SWITCH) AVAILABILITY (%)-PLANLI HARIC   99.403825
# 44  KPI-FTTB (SWITCH) GUNDUZ AVAILABILITY (%)-PLAN...   99.112246
# 45             KPI-FTTB POP (SWITCH) AVAILABILITY (%)   98.905691
# 46      KPI-FTTB POP (SWITCH) GUNDUZ AVAILABILITY (%)   98.358536
# 47  KPI-FTTB POP (SWITCH) AVAILABILITY (%)-PLANLI ...   98.905691
# 48  KPI-FTTB POP (SWITCH) GUNDUZ AVAILABILITY (%)-...   98.358536
